# %% [markdown]
# <a href="https://colab.research.google.com/github/sibasishsahu68/DMPM-Lab/blob/main/Experiment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#write a program to find the largest of three numbers

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))
largest = a
if b > largest:
    largest = b
if c > largest:
    largest = c
print("The largest number is:", largest)
# Out:
# Enter first number: 5
# Enter second number: 6
# Enter third number: 8
# The largest number is: 8.0

# %%
#write a program to check whether a number is even or odd
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd")
# Out:
# Enter a number: 5
# The number is odd

# %%
# write a program to swap two numbers without using a third variable
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Before swapping: a =", a, "b =", b)
a = a + b
b = a - b
a = a - b
print("After swapping: a =", a, "b =", b)
# Out:
# Enter first number: 354
# Enter second number: 54
# Before swapping: a = 354.0 b = 54.0
# After swapping: a = 54.0 b = 354.0

# %%
#write a program to check whether a string is a palindrome

string = input("Enter a string: ")
flag = True
for i in range(len(string) // 2):
    if string[i] != string[len(string) - i - 1]:
        flag = False
        break
if flag:
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")
# Out:
# Enter a string: okko
# The string is a palindrome.

# %%
# write a program to implement a simple calculator

num1 = float(input("Enter first number: "))
operator = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))

result = None

if operator == '+':
    result = num1 + num2
elif operator == '-':
    result = num1 - num2
elif operator == '*':
    result = num1 * num2
elif operator == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        print("Error: Division by zero is not allowed.")
else:
    print("Error: Invalid operator.")

if result is not None:
    print(f"The result is: {result}")
# Out:
# Enter first number: 4
# Enter operator (+, -, *, /): -
# Enter second number: 2
# The result is: 2.0

# %%
# write a program to count vowels in a string
string = input("Enter a string: ")
vowels = [l for l in string if l in 'aeiouAEIOU']
print("The number of vowels in the string is:", len(vowels))

# %%
#write a program to check whether a number is prime

num = int(input("Enter a number: "))
if num > 1:
    for i in range(2, int(num**0.5) + 1):
        if (num % i) == 0:
            print(num, "is not a prime number.")
            break
    else:
        print(num, "is a prime number.")
# Out:
# Enter a number: 4
# 4 is not a prime number.

# %%
# write a program to find th sum of digits of a number
num = int(input("Enter a number: "))
sum_of_digits = sum(int(digit) for digit in str(num))
print("The sum of digits of the number is:", sum_of_digits)
# Out:
# Enter a number: 65
# The sum of digits of the number is: 11

# %%
# write a program to reverse a number.
num = int(input("Enter a number: "))
reverse_num = 0
while num > 0:
    digit = num % 10
    reverse_num = reverse_num * 10 + digit
    num //= 10
print("The reverse of the number is:", reverse_num)
# Out:
# Enter a number: 54
# The reverse of the number is: 45

# %%
# write a program to find the factorial of a number
num = int(input("Enter a number: "))
fact = 1
for i in range(1, num + 1):
    fact *= i
print("The factorial of the number is:", fact)
