# %% [markdown]
# <a href="https://colab.research.google.com/github/sibasishsahu68/DMPM-Lab/blob/main/Experiment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num =[int(y) for y in input("Enter numbers separated by commas: ").split(",")]
mean = sum(num)/len(num)
print(mean)
# Out:
# Enter numbers separated by commas: 1,2,3,4
# 2.5

# %%
import numpy as np
mean = np.mean([1,2,3,4,5,6])
print(mean)
# Out:
# 3.5

# %%
data = [int(x) for x in input ("Enter numbers:").split(",")]
if len (data)%2==0:
  median = (data[len(data)//2]+data[len(data)//2-1])/2
else:
  median = data[len(data)//2]
print(median)
# Out:
# Enter numbers:2,3,4,5,6
# 4

# %%
import numpy as np
x = np.array([23,34,45,56,67,78,89])
median = np.median(x)
print (f"Median is : {median}")
# Out:
# Median is : 56.0

# %%
l = [int(x) for x in input("Enter the list of number :").split(",")]
dict = {}
for x in l:
    if x in dict:
        dict[x] += 1
    else:
        dict[x] = 1
mode = max(dict, key=dict.get)
print(mode)
# Out:
# Enter the list of number :21,5614,514,5,6
# 21

# %%
l = [int(x) for x in input("Enter the list of number :").split(",")]
mode_with = np.bincount(l).argmax()
print(mode_with)
# Out:
# Enter the list of number :2,1
# 1

# %%
l = [int(x) for x in input("Enter the list of number :").split(",")]
mean = sum(l)/len(l)
sum_squared_diff = sum((x - mean) ** 2 for x in l)
variance = sum_squared_diff / len(l)
print(f"Varience without using function : {variance:.4f}")
# Out:
# Enter the list of number :23,56,54,87
# Varience without using function : 512.5000

# %%
l = [int(x) for x in input("Enter the list of number :").split(",")]
l = np.array(l)
variance = np.var(l)
print(f"Varience with using function : {variance:.4f}")
# Out:
# Enter the list of number :21,54,87
# Varience with using function : 726.0000

# %%
l = [int(x) for x in input("Enter the list of number :").split(",")]
mean = sum(l)/len(l)
sum_squared_diff = sum((x - mean) ** 2 for x in l)
sd = (sum_squared_diff / len(l))**0.5
print(f"Standard Deviation without function : {sd:.4f}")

l2 = np.array(l)
sd = np.std(l2)
print(f"Standard Deviation with using function : {sd:.4f}")
# Out:
# Enter the list of number :54,65,98
# Standard Deviation without function : 18.6964
# Standard Deviation with using function : 18.6964

# %%
l = [int(x) for x in input("Enter the list of number :").split(",")]
mean = sum(l)/len(l)
sum_squared_diff = sum((x - mean) ** 2 for x in l)
variance = sum_squared_diff / len(l)
print(f"Varience without using function : {variance:.4f}")
sd = variance**0.5
print(f"Standard Deviation without function : {sd:.4f}")
# Out:
# Enter the list of number :54
# Varience without using function : 0.0000
# Standard Deviation without function : 0.0000
